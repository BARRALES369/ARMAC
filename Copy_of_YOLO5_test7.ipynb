# %% [markdown]
# <a href="https://colab.research.google.com/github/BARRALES369/ARMAC/blob/Computer_Vision/Copy_of_YOLO5_test7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/ultralytics/yolov5
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 17270, done.
# remote: Counting objects: 100% (1/1), done.
# remote: Total 17270 (delta 0), reused 0 (delta 0), pack-reused 17269 (from 2)
# Receiving objects: 100% (17270/17270), 16.12 MiB | 11.70 MiB/s, done.
# Resolving deltas: 100% (11858/11858), done.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd yolov5
# Out:
# /content/drive/MyDrive/Colab Notebooks/YOLO5_test7/yolov5

# %%
# %pip install -qr requirements.txt comet_ml  # install

# %%
# !python train.py --img 640 --batch 16 --epochs 3 --data vehicles_open_image/data_vehicles_5classes.yaml --weights yolov5s.pt --cache
# Out:
# wandb: WARNING ⚠️ wandb is deprecated and will be removed in a future release. See supported integrations at https://github.com/ultralytics/yolov5#integrations.
# 2025-02-25 13:27:17.036083: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1740490037.082057   21033 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1740490037.096167   21033 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# wandb: (1) Create a W&B account
# wandb: (2) Use an existing W&B account
# wandb: (3) Don't visualize my results
# wandb: Enter your choice: (30 second timeout)
# ...

# %%
# !python train.py --img 640 --batch 16 --epochs 3 --data vehicles_open_image/data_vehicles_5classes.yaml --weights /content/drive/MyDrive/Colab_Notebooks/YOLO5_test7/yolov5/projects/vehicles_open_image_test1/exp/weights/best.pt --cache
# Out:
# wandb: WARNING ⚠️ wandb is deprecated and will be removed in a future release. See supported integrations at https://github.com/ultralytics/yolov5#integrations.
# 2025-02-25 15:02:25.601714: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1740495745.654015   44614 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1740495745.669931   44614 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# wandb: (1) Create a W&B account
# wandb: (2) Use an existing W&B account
# wandb: (3) Don't visualize my results
# wandb: Enter your choice: (30 second timeout)
# ...

# %%
# !python train.py --img 640 --batch 16 --epochs 3 --data vehicles_open_image/data_vehicles_5classes.yaml --weights /content/drive/MyDrive/Colab_Notebooks/YOLO5_test7/yolov5/projects/vehicles_open_image_test1/exp/weights/last.pt --cache
# Out:
# wandb: WARNING ⚠️ wandb is deprecated and will be removed in a future release. See supported integrations at https://github.com/ultralytics/yolov5#integrations.
# 2025-02-25 16:43:46.694954: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1740501826.774145   69245 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1740501826.800624   69245 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# wandb: (1) Create a W&B account
# wandb: (2) Use an existing W&B account
# wandb: (3) Don't visualize my results
# wandb: Enter your choice: (30 second timeout)
# ...

# %%
# %cd /content/drive/MyDrive/Colab_Notebooks/YOLO5_test7/yolov5
# Out:
# /content/drive/MyDrive/Colab_Notebooks/YOLO5_test7/yolov5

# %%
pip install -r requirements.txt  # install dependencies
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 77.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 51.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 44.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 2.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 54.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 921.8/921.8 kB 40.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
# !python detect.py --weights yolov5s.pt --source /content/drive/MyDrive/Colab_Notebooks/YOLO5_test7/yolov5/data/images/zidane.jpg
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# detect: weights=['yolov5s.pt'], source=/content/drive/MyDrive/Colab_Notebooks/YOLO5_test7/yolov5/data/images/zidane.jpg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_format=0, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-398-g5cdad892 Python-3.11.11 torch-2.5.1+cu124 CPU
#
# Fusing layers...
# ...

# %%
# !python detect.py --weights yolov5s.pt --source /content/drive/MyDrive/Colab_Notebooks/YOLO5_test7/yolov5/data/images/zidane.jpg --imgsz 1024
# Out:
# detect: weights=['yolov5s.pt'], source=/content/drive/MyDrive/Colab_Notebooks/YOLO5_test7/yolov5/data/images/zidane.jpg, data=data/coco128.yaml, imgsz=[1024, 1024], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_format=0, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-398-g5cdad892 Python-3.11.11 torch-2.5.1+cu124 CPU
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients, 16.4 GFLOPs
# image 1/1 /content/drive/MyDrive/Colab_Notebooks/YOLO5_test7/yolov5/data/images/zidane.jpg: 576x1024 2 persons, 1 tie, 1121.6ms
# Speed: 12.0ms pre-process, 1121.6ms inference, 9.1ms NMS per image at shape (1, 3, 1024, 1024)
# Results saved to runs/detect/exp2

# %%
# !python detect.py --weights yolov5s.pt --source /content/drive/MyDrive/Colab_Notebooks/YOLO5_test7/yolov5/data/images/zidane.jpg --imgsz 240
# Out:
# detect: weights=['yolov5s.pt'], source=/content/drive/MyDrive/Colab_Notebooks/YOLO5_test7/yolov5/data/images/zidane.jpg, data=data/coco128.yaml, imgsz=[240, 240], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_format=0, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-398-g5cdad892 Python-3.11.11 torch-2.5.1+cu124 CPU
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients, 16.4 GFLOPs
# WARNING ⚠️ --img-size [240, 240] must be multiple of max stride 32, updating to [256, 256]
# image 1/1 /content/drive/MyDrive/Colab_Notebooks/YOLO5_test7/yolov5/data/images/zidane.jpg: 160x256 2 persons, 1 tie, 62.1ms
# ...

# %%
# !python detect.py --weights yolov5s.pt --source /content/drive/MyDrive/Colab_Notebooks/YOLO5_test7/yolov5/data/images/zidane.jpg --conf-thres=0.15
# Out:
# detect: weights=['yolov5s.pt'], source=/content/drive/MyDrive/Colab_Notebooks/YOLO5_test7/yolov5/data/images/zidane.jpg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.15, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_format=0, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-398-g5cdad892 Python-3.11.11 torch-2.5.1+cu124 CPU
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients, 16.4 GFLOPs
# image 1/1 /content/drive/MyDrive/Colab_Notebooks/YOLO5_test7/yolov5/data/images/zidane.jpg: 384x640 2 persons, 2 ties, 1 cell phone, 487.0ms
# Speed: 6.0ms pre-process, 487.0ms inference, 5.7ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp4

# %%
# !python detect.py --weights yolov5s.pt --source /content/drive/MyDrive/Colab_Notebooks/YOLO5_test7/yolov5/data/images/zidane.jpg --conf-thres=0.9
# Out:
# detect: weights=['yolov5s.pt'], source=/content/drive/MyDrive/Colab_Notebooks/YOLO5_test7/yolov5/data/images/zidane.jpg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.9, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_format=0, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-398-g5cdad892 Python-3.11.11 torch-2.5.1+cu124 CPU
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients, 16.4 GFLOPs
# image 1/1 /content/drive/MyDrive/Colab_Notebooks/YOLO5_test7/yolov5/data/images/zidane.jpg: 384x640 (no detections), 305.4ms
# Speed: 2.5ms pre-process, 305.4ms inference, 2.1ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp5

# %%
# !python detect.py --weights yolov5s.pt --source /content/drive/MyDrive/Colab_Notebooks/YOLO5_test7/yolov5/data/images/zidane.jpg --iou-thres=0.2
# Out:
# detect: weights=['yolov5s.pt'], source=/content/drive/MyDrive/Colab_Notebooks/YOLO5_test7/yolov5/data/images/zidane.jpg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.2, max_det=1000, device=, view_img=False, save_txt=False, save_format=0, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-398-g5cdad892 Python-3.11.11 torch-2.5.1+cu124 CPU
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients, 16.4 GFLOPs
# image 1/1 /content/drive/MyDrive/Colab_Notebooks/YOLO5_test7/yolov5/data/images/zidane.jpg: 384x640 2 persons, 2 ties, 319.3ms
# Speed: 5.9ms pre-process, 319.3ms inference, 3.6ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp6

# %%
# !python detect.py --weights yolov5s.pt --source /content/drive/MyDrive/Colab_Notebooks/YOLO5_test7/yolov5/data/images/zidane.jpg --iou-thres=0.9
# Out:
# detect: weights=['yolov5s.pt'], source=/content/drive/MyDrive/Colab_Notebooks/YOLO5_test7/yolov5/data/images/zidane.jpg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.9, max_det=1000, device=, view_img=False, save_txt=False, save_format=0, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-398-g5cdad892 Python-3.11.11 torch-2.5.1+cu124 CPU
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients, 16.4 GFLOPs
# image 1/1 /content/drive/MyDrive/Colab_Notebooks/YOLO5_test7/yolov5/data/images/zidane.jpg: 384x640 5 persons, 4 ties, 307.2ms
# Speed: 4.7ms pre-process, 307.2ms inference, 3.7ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp7

# %%
# !python detect.py --weights yolov5s.pt --source /content/drive/MyDrive/Colab_Notebooks/YOLO5_test7/yolov5/data/images/zidane.jpg --max-det=50
# Out:
# detect: weights=['yolov5s.pt'], source=/content/drive/MyDrive/Colab_Notebooks/YOLO5_test7/yolov5/data/images/zidane.jpg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=50, device=, view_img=False, save_txt=False, save_format=0, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-398-g5cdad892 Python-3.11.11 torch-2.5.1+cu124 CPU
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients, 16.4 GFLOPs
# image 1/1 /content/drive/MyDrive/Colab_Notebooks/YOLO5_test7/yolov5/data/images/zidane.jpg: 384x640 2 persons, 2 ties, 306.0ms
# Speed: 3.2ms pre-process, 306.0ms inference, 3.3ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp8

# %%
# !python detect.py --weights yolov5s.pt --source /content/drive/MyDrive/Colab_Notebooks/YOLO5_test7/yolov5/data/images/zidane.jpg --max-det=900
# Out:
# detect: weights=['yolov5s.pt'], source=/content/drive/MyDrive/Colab_Notebooks/YOLO5_test7/yolov5/data/images/zidane.jpg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=900, device=, view_img=False, save_txt=False, save_format=0, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-398-g5cdad892 Python-3.11.11 torch-2.5.1+cu124 CPU
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients, 16.4 GFLOPs
# image 1/1 /content/drive/MyDrive/Colab_Notebooks/YOLO5_test7/yolov5/data/images/zidane.jpg: 384x640 2 persons, 2 ties, 309.7ms
# Speed: 2.4ms pre-process, 309.7ms inference, 2.3ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp9

# %%
# !pip install yt-dlp ffmpeg-python
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 171.9/171.9 kB 7.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 60.4 MB/s eta 0:00:00
# ...

# %%
# !yt-dlp -g "https://www.youtube.com/watch?v=h7ZZTw93fc4" -o "video_stream"
# Out:
# https://rr4---sn-5hne6nsd.googlevideo.com/videoplayback?expire=1740546289&ei=kUy-Z-elDa-G6dsPwJjw0Ak&ip=34.141.136.46&id=o-AMiTvQ24Yc6XtgqXFQwlAxk8yMP6ROBBCbMCck5AN8dG&itag=399&aitags=133%2C134%2C135%2C136%2C137%2C160%2C242%2C243%2C244%2C247%2C248%2C278%2C394%2C395%2C396%2C397%2C398%2C399&source=youtube&requiressl=yes&xpc=EgVo2aDSNQ%3D%3D&met=1740524689%2C&mh=LP&mm=31%2C26&mn=sn-5hne6nsd%2Csn-a5meknzk&ms=au%2Conr&mv=u&mvi=4&pl=20&rms=au%2Cau&bui=AUWDL3yHVd0tZN05_i2JvRnoL3Otcfh1yY2RQdaPHUKSnjQP7uKjSbYGY2D7PPxUs-2Ssc5o9Xmu17yP&spc=RjZbSXaFXjvPSzrJmo9ed82ECx7dx6He6WjuzyIQcyHld2y0KGDIVV6J6Mc9WUGPEw5fgw&vprv=1&svpuc=1&mime=video%2Fmp4&ns=SVkY0lKKeRmWgT2Qd0kJX2cQ&rqh=1&gir=yes&clen=22613549&dur=177.076&lmt=1737098804067324&mt=1740523525&fvip=2&keepalive=yes&lmw=1&fexp=51326932%2C51410170&c=TVHTML5&sefc=1&txp=543G534&n=oiuLAEFoJibEUg&sparams=expire%2Cei%2Cip%2Cid%2Caitags%2Csource%2Crequiressl%2Cxpc%2Cbui%2Cspc%2Cvprv%2Csvpuc%2Cmime%2Cns%2Crqh%2Cgir%2Cclen%2Cdur%2Clmt&sig=AJfQdSswRgIhALyoO_
# ...

# %%
# !python detect.py --weights yolov5s.pt --source "https://youtu.be/h7ZZTw93fc4?si=RBXxVAEwp2M3tLI9"
# Out:
# detect: weights=['yolov5s.pt'], source=https://youtu.be/h7ZZTw93fc4?si=RBXxVAEwp2M3tLI9, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_format=0, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-398-g5cdad892 Python-3.11.11 torch-2.5.1+cu124 CPU
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients, 16.4 GFLOPs
# WARNING ⚠️ Environment does not support cv2.imshow() or PIL Image.show()
#
# [ WARN:0@6.057] global cap.cpp:175 open VIDEOIO(CV_IMAGES): raised OpenCV exception:
#
# ...
